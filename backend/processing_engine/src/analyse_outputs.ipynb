# %%
import os
import importlib
from solver_parameter_tuning import analyse_outputs_utils

importlib.reload(analyse_outputs_utils)
# Out:
# <module 'solver_parameter_tuning.analyse_outputs_utils' from '/Users/felipekharaba/Documents/Documents – Felipe’s MacBook Pro/nsp_pro/backend/processing_engine/src/solver_parameter_tuning/analyse_outputs_utils.py'>

# %%
current_folder = os.getcwd()
dir_path_output = os.path.join(
    current_folder,
    "solver_parameter_tuning/parameter_test_output",
)
# data = analyse_outputs_utils.process_json_files(dir_path_output)
# df = analyse_outputs_utils.calculate_averages(data)
df = analyse_outputs_utils.build_output_table(dir_path_output)
df
# Out:
#                                                       base_case  \
# best_bound                                                   13
# booleans                                                  51203
# branches                                                 136513
# conflicts                                                     0
# deterministic_time                                           28
# gap_integral                                                289
# integer_propagations                                    4149772
# integers                                                  63497
# lp_iterations                                             48790
# objective                                                 26899
# propagations                                             888558
# restarts                                                  45824
# run_timestamp                                        1741106946
# solution_fingerprint                         0x67ed0727da087db6
# status                                                 FEASIBLE
# usertime                                                     30
# walltime                                                     30
# ---
# core_minimization_level                                       2
# cp_model_probing_level                                        0
# detect_table_with_cost                                    False
# diversify_lns_params                                      False
# interleave_search                                         False
# linearization_level                                           1
# log_search_progress                                        True
# max_presolve_iterations                                       3
# max_time_in_seconds                                          30
# num_search_workers                                            2
# optimize_with_core                                        False
# probing_deterministic_time_limit                            1.0
# random_seed                                                   1
# subsolvers                                                 None
# symmetry_detection_deterministic_time_limit                   1
# symmetry_level                                                2
# use_lns_only                                              False
# use_symmetry_in_lp                                        False
#
#                                                       base_case  \
# best_bound                                                   13
# booleans                                                  51153
# branches                                                 128156
# conflicts                                                     0
# deterministic_time                                           15
# gap_integral                                                160
# integer_propagations                                    4774266
# integers                                                  63497
# lp_iterations                                             26089
# objective                                                298409
# propagations                                            1194915
# restarts                                                 102306
# run_timestamp                                        1741109859
# solution_fingerprint                         0x3b476817b47e851c
# status                                                 FEASIBLE
# usertime                                                     39
# walltime                                                     39
# ---
# core_minimization_level                                       2
# cp_model_probing_level                                        2
# detect_table_with_cost                                    False
# diversify_lns_params                                      False
# interleave_search                                         False
# linearization_level                                           1
# log_search_progress                                        True
# max_presolve_iterations                                       3
# max_time_in_seconds                                          30
# num_search_workers                                            2
# optimize_with_core                                        False
# probing_deterministic_time_limit                            1.0
# random_seed                                                   1
# subsolvers                                                 None
# symmetry_detection_deterministic_time_limit                   1
# symmetry_level                                                2
# use_lns_only                                              False
# use_symmetry_in_lp                                         True
#
#                                             core_minimization_level_1  \
# best_bound                                                         13
# booleans                                                        51153
# branches                                                       108781
# conflicts                                                           0
# deterministic_time                                                 10
# gap_integral                                                      111
# integer_propagations                                          4599629
# integers                                                        63497
# lp_iterations                                                   18131
# objective                                                      311811
# propagations                                                  1183471
# restarts                                                       102306
# run_timestamp                                              1741102105
# solution_fingerprint                               0xb4a293b8117a3242
# status                                                       FEASIBLE
# usertime                                                           31
# walltime                                                           31
# ---
# core_minimization_level                                             2
# cp_model_probing_level                                              2
# detect_table_with_cost                                          False
# diversify_lns_params                                            False
# interleave_search                                                True
# linearization_level                                                 1
# log_search_progress                                              True
# max_presolve_iterations                                             3
# max_time_in_seconds                                                30
# num_search_workers                                                  2
# optimize_with_core                                              False
# probing_deterministic_time_limit                                  1.0
# random_seed                                                         1
# subsolvers                                                       None
# symmetry_detection_deterministic_time_limit                         1
# symmetry_level                                                      2
# use_lns_only                                                    False
# use_symmetry_in_lp                                              False
#
#                                             cp_model_probing_level_0  \
# best_bound                                                        13
# booleans                                                       51153
# branches                                                      131602
# conflicts                                                          0
# deterministic_time                                                17
# gap_integral                                                     190
# integer_propagations                                         4804847
# integers                                                       63497
# lp_iterations                                                  30956
# objective                                                     262262
# propagations                                                 1197420
# restarts                                                      102306
# run_timestamp                                             1741098653
# solution_fingerprint                              0x1892bfc1444d59e5
# status                                                      FEASIBLE
# usertime                                                          30
# walltime                                                          30
# ---
# core_minimization_level                                            2
# cp_model_probing_level                                             2
# detect_table_with_cost                                         False
# diversify_lns_params                                           False
# interleave_search                                              False
# linearization_level                                                2
# log_search_progress                                             True
# max_presolve_iterations                                            3
# max_time_in_seconds                                               30
# num_search_workers                                                 2
# optimize_with_core                                             False
# probing_deterministic_time_limit                                 1.0
# random_seed                                                        1
# subsolvers                                                      None
# symmetry_detection_deterministic_time_limit                        1
# symmetry_level                                                     2
# use_lns_only                                                   False
# use_symmetry_in_lp                                             False
#
#                                             cp_model_probing_level_1  \
# best_bound                                                        13
# booleans                                                       51153
# branches                                                      131423
# conflicts                                                          0
# deterministic_time                                                17
# gap_integral                                                     186
# integer_propagations                                         4803075
# integers                                                       63497
# lp_iterations                                                  30915
# objective                                                     277639
# propagations                                                 1197305
# restarts                                                      102306
# run_timestamp                                             1741097964
# solution_fingerprint                              0x4b1fc56f76feb700
# status                                                      FEASIBLE
# usertime                                                          30
# walltime                                                          30
# ---
# core_minimization_level                                            2
# cp_model_probing_level                                             2
# detect_table_with_cost                                         False
# diversify_lns_params                                           False
# interleave_search                                              False
# linearization_level                                                1
# log_search_progress                                             True
# max_presolve_iterations                                            3
# max_time_in_seconds                                               30
# num_search_workers                                                 2
# optimize_with_core                                             False
# probing_deterministic_time_limit                                 1.0
# random_seed                                                        1
# subsolvers                                                      None
# symmetry_detection_deterministic_time_limit                        1
# symmetry_level                                                     2
# use_lns_only                                                   False
# use_symmetry_in_lp                                             False
#
#                                             cp_model_probing_level_3  \
# best_bound                                                        13
# booleans                                                       51153
# branches                                                      131243
# conflicts                                                          0
# deterministic_time                                                16
# gap_integral                                                     178
# integer_propagations                                         4800089
# integers                                                       63497
# lp_iterations                                                  28425
# objective                                                     248033
# propagations                                                 1196940
# restarts                                                      102306
# run_timestamp                                             1741105216
# solution_fingerprint                              0x39ca0ca663c2f4a4
# status                                                      FEASIBLE
# usertime                                                          30
# walltime                                                          30
# ---
# core_minimization_level                                            2
# cp_model_probing_level                                             2
# detect_table_with_cost                                         False
# diversify_lns_params                                           False
# interleave_search                                              False
# linearization_level                                                1
# log_search_progress                                             True
# max_presolve_iterations                                            3
# max_time_in_seconds                                               30
# num_search_workers                                                 2
# optimize_with_core                                             False
# probing_deterministic_time_limit                                 5.0
# random_seed                                                        1
# subsolvers                                                      None
# symmetry_detection_deterministic_time_limit                        1
# symmetry_level                                                     2
# use_lns_only                                                   False
# use_symmetry_in_lp                                             False
#
#                                             detect_table_with_cost_True  \
# best_bound                                                           13
# booleans                                                          51153
# branches                                                         131350
# conflicts                                                             0
# deterministic_time                                                   15
# gap_integral                                                        160
# integer_propagations                                            4802366
# integers                                                          63497
# lp_iterations                                                     30905
# objective                                                        249503
# propagations                                                    1197260
# restarts                                                         102306
# run_timestamp                                                1741098308
# solution_fingerprint                                 0xa7bf0e8a584562e1
# status                                                         FEASIBLE
# usertime                                                             30
# walltime                                                             30
# ---
# core_minimization_level                                               2
# cp_model_probing_level                                                2
# detect_table_with_cost                                            False
# diversify_lns_params                                              False
# interleave_search                                                 False
# linearization_level                                                   0
# log_search_progress                                                True
# max_presolve_iterations                                               3
# max_time_in_seconds                                                  30
# num_search_workers                                                    2
# optimize_with_core                                                False
# probing_deterministic_time_limit                                    1.0
# random_seed                                                           1
# subsolvers                                                         None
# symmetry_detection_deterministic_time_limit                           1
# symmetry_level                                                        2
# use_lns_only                                                      False
# use_symmetry_in_lp                                                False
#
#                                             diversify_lns_params_True  \
# best_bound                                                         13
# booleans                                                        51153
# branches                                                       131123
# conflicts                                                           0
# deterministic_time                                                 16
# gap_integral                                                      178
# integer_propagations                                          4798868
# integers                                                        63497
# lp_iterations                                                   28394
# objective                                                      257054
# propagations                                                  1196850
# restarts                                                       102306
# run_timestamp                                              1741109072
# solution_fingerprint                               0x21a7d2d83a8d6223
# status                                                       FEASIBLE
# usertime                                                           30
# walltime                                                           30
# ---
# core_minimization_level                                             2
# cp_model_probing_level                                              2
# detect_table_with_cost                                          False
# diversify_lns_params                                            False
# interleave_search                                               False
# linearization_level                                                 1
# log_search_progress                                              True
# max_presolve_iterations                                             3
# max_time_in_seconds                                                30
# num_search_workers                                                  2
# optimize_with_core                                              False
# probing_deterministic_time_limit                                  1.0
# random_seed                                                         1
# subsolvers                                                       None
# symmetry_detection_deterministic_time_limit                         1
# symmetry_level                                                      3
# use_lns_only                                                    False
# use_symmetry_in_lp                                              False
#
#                                             interleave_search_True  \
# best_bound                                                      13
# booleans                                                     51153
# branches                                                    130464
# conflicts                                                        0
# deterministic_time                                              16
# gap_integral                                                   173
# integer_propagations                                       4792410
# integers                                                     63497
# lp_iterations                                                28255
# objective                                                   310553
# propagations                                               1196418
# restarts                                                    102306
# run_timestamp                                           1741106600
# solution_fingerprint                             0x5263f0f939cb14d
# status                                                    FEASIBLE
# usertime                                                        30
# walltime                                                        30
# ---
# core_minimization_level                                          2
# cp_model_probing_level                                           2
# detect_table_with_cost                                       False
# diversify_lns_params                                         False
# interleave_search                                            False
# linearization_level                                              1
# log_search_progress                                           True
# max_presolve_iterations                                         10
# max_time_in_seconds                                             30
# num_search_workers                                               2
# optimize_with_core                                           False
# probing_deterministic_time_limit                               1.0
# random_seed                                                      1
# subsolvers                                                    None
# symmetry_detection_deterministic_time_limit                      1
# symmetry_level                                                   2
# use_lns_only                                                 False
# use_symmetry_in_lp                                           False
#
#                                             linearization_level_0  ...  \
# best_bound                                                     13  ...
# booleans                                                    51153  ...
# branches                                                   131001  ...
# conflicts                                                       0  ...
# deterministic_time                                             16  ...
# gap_integral                                                  181  ...
# integer_propagations                                      4797734  ...
# integers                                                    63497  ...
# lp_iterations                                               28396  ...
# objective                                                  267456  ...
# propagations                                              1196785  ...
# restarts                                                   102306  ...
# run_timestamp                                          1741103836  ...
# solution_fingerprint                            0x2f199b1bd8c76c4  ...
# status                                                   FEASIBLE  ...
# usertime                                                       30  ...
# walltime                                                       30  ...
# ---                                                                ...
# core_minimization_level                                         2  ...
# cp_model_probing_level                                          2  ...
# detect_table_with_cost                                      False  ...
# diversify_lns_params                                        False  ...
# interleave_search                                           False  ...
# linearization_level                                             1  ...
# log_search_progress                                          True  ...
# max_presolve_iterations                                         3  ...
# max_time_in_seconds                                            30  ...
# num_search_workers                                              2  ...
# optimize_with_core                                          False  ...
# probing_deterministic_time_limit                              1.0  ...
# random_seed                                                   789  ...
# subsolvers                                                   None  ...
# symmetry_detection_deterministic_time_limit                     1  ...
# symmetry_level                                                  2  ...
# use_lns_only                                                False  ...
# use_symmetry_in_lp                                          False  ...
#
#                                                  random_seed_42  \
# best_bound                                                   13
# booleans                                                  51153
# branches                                                 131009
# conflicts                                                     0
# deterministic_time                                           16
# gap_integral                                                178
# integer_propagations                                    4797782
# integers                                                  63497
# lp_iterations                                             28389
# objective                                                260682
# propagations                                            1196783
# restarts                                                 102306
# run_timestamp                                        1741107638
# solution_fingerprint                         0x549dfa28ea039d4f
# status                                                 FEASIBLE
# usertime                                                     30
# walltime                                                     30
# ---
# core_minimization_level                                       2
# cp_model_probing_level                                        3
# detect_table_with_cost                                    False
# diversify_lns_params                                      False
# interleave_search                                         False
# linearization_level                                           1
# log_search_progress                                        True
# max_presolve_iterations                                       3
# max_time_in_seconds                                          30
# num_search_workers                                            2
# optimize_with_core                                        False
# probing_deterministic_time_limit                            1.0
# random_seed                                                   1
# subsolvers                                                 None
# symmetry_detection_deterministic_time_limit                   1
# symmetry_level                                                2
# use_lns_only                                              False
# use_symmetry_in_lp                                        False
#
#                                                 random_seed_789  \
# best_bound                                                   13
# booleans                                                  51153
# branches                                                 129301
# conflicts                                                     0
# deterministic_time                                           15
# gap_integral                                                171
# integer_propagations                                    4782029
# integers                                                  63497
# lp_iterations                                             27997
# objective                                                268214
# propagations                                            1195875
# restarts                                                 102306
# run_timestamp                                        1741109419
# solution_fingerprint                         0x73a33687a784a73a
# status                                                 FEASIBLE
# usertime                                                     30
# walltime                                                     30
# ---
# core_minimization_level                                       2
# cp_model_probing_level                                        2
# detect_table_with_cost                                    False
# diversify_lns_params                                      False
# interleave_search                                         False
# linearization_level                                           1
# log_search_progress                                        True
# max_presolve_iterations                                       3
# max_time_in_seconds                                          30
# num_search_workers                                            2
# optimize_with_core                                        False
# probing_deterministic_time_limit                            1.0
# random_seed                                                   1
# subsolvers                                                 None
# symmetry_detection_deterministic_time_limit                   1
# symmetry_level                                                4
# use_lns_only                                              False
# use_symmetry_in_lp                                        False
#
#                                             symmetry_detection_deterministic_time_limit_0  \
# best_bound                                                                             13
# booleans                                                                            51153
# branches                                                                           131912
# conflicts                                                                               0
# deterministic_time                                                                     16
# gap_integral                                                                          195
# integer_propagations                                                              4806303
# integers                                                                            63497
# lp_iterations                                                                       28416
# objective                                                                          209951
# propagations                                                                      1197308
# restarts                                                                           102306
# run_timestamp                                                                  1741105562
# solution_fingerprint                                                   0x39a7a7fff7f87323
# status                                                                           FEASIBLE
# usertime                                                                               30
# walltime                                                                               30
# ---
# core_minimization_level                                                                 2
# cp_model_probing_level                                                                  2
# detect_table_with_cost                                                              False
# diversify_lns_params                                                                False
# interleave_search                                                                   False
# linearization_level                                                                     1
# log_search_progress                                                                  True
# max_presolve_iterations                                                                 1
# max_time_in_seconds                                                                    30
# num_search_workers                                                                      2
# optimize_with_core                                                                  False
# probing_deterministic_time_limit                                                      1.0
# random_seed                                                                             1
# subsolvers                                                                           None
# symmetry_detection_deterministic_time_limit                                             1
# symmetry_level                                                                          2
# use_lns_only                                                                        False
# use_symmetry_in_lp                                                                  False
#
#                                             symmetry_detection_deterministic_time_limit_2  \
# best_bound                                                                             13
# booleans                                                                            51153
# branches                                                                           130638
# conflicts                                                                               0
# deterministic_time                                                                     16
# gap_integral                                                                          177
# integer_propagations                                                              4794272
# integers                                                                            63497
# lp_iterations                                                                       28302
# objective                                                                          263728
# propagations                                                                      1196570
# restarts                                                                           102306
# run_timestamp                                                                  1741110896
# solution_fingerprint                                                   0x4c5f682cea595571
# status                                                                           FEASIBLE
# usertime                                                                               30
# walltime                                                                               30
# ---
# core_minimization_level                                                                 2
# cp_model_probing_level                                                                  2
# detect_table_with_cost                                                              False
# diversify_lns_params                                                                False
# interleave_search                                                                   False
# linearization_level                                                                     1
# log_search_progress                                                                  True
# max_presolve_iterations                                                                 3
# max_time_in_seconds                                                                    30
# num_search_workers                                                                      2
# optimize_with_core                                                                  False
# probing_deterministic_time_limit                                                      1.0
# random_seed                                                                             1
# subsolvers                                                                           None
# symmetry_detection_deterministic_time_limit                                             5
# symmetry_level                                                                          2
# use_lns_only                                                                        False
# use_symmetry_in_lp                                                                  False
#
#                                             symmetry_detection_deterministic_time_limit_5  \
# best_bound                                                                             13
# booleans                                                                            51153
# branches                                                                           131139
# conflicts                                                                               0
# deterministic_time                                                                     17
# gap_integral                                                                          189
# integer_propagations                                                              4799091
# integers                                                                            63497
# lp_iterations                                                                       28414
# objective                                                                          242840
# propagations                                                                      1196876
# restarts                                                                           102306
# run_timestamp                                                                  1741103145
# solution_fingerprint                                                   0x68478c9d57858484
# status                                                                           FEASIBLE
# usertime                                                                               30
# walltime                                                                               30
# ---
# core_minimization_level                                                                 2
# cp_model_probing_level                                                                  2
# detect_table_with_cost                                                              False
# diversify_lns_params                                                                False
# interleave_search                                                                   False
# linearization_level                                                                     1
# log_search_progress                                                                  True
# max_presolve_iterations                                                                 3
# max_time_in_seconds                                                                    30
# num_search_workers                                                                      2
# optimize_with_core                                                                  False
# probing_deterministic_time_limit                                                      1.0
# random_seed                                                                            42
# subsolvers                                                                           None
# symmetry_detection_deterministic_time_limit                                             1
# symmetry_level                                                                          2
# use_lns_only                                                                        False
# use_symmetry_in_lp                                                                  False
#
#                                                symmetry_level_1  \
# best_bound                                                   13
# booleans                                                  51153
# branches                                                 131184
# conflicts                                                     0
# deterministic_time                                           16
# gap_integral                                                179
# integer_propagations                                    4799538
# integers                                                  63497
# lp_iterations                                             28422
# objective                                                248840
# propagations                                            1196905
# restarts                                                 102306
# run_timestamp                                        1741102800
# solution_fingerprint                         0x4d26d6e989b7c33a
# status                                                 FEASIBLE
# usertime                                                     30
# walltime                                                     30
# ---
# core_minimization_level                                       1
# cp_model_probing_level                                        2
# detect_table_with_cost                                    False
# diversify_lns_params                                      False
# interleave_search                                         False
# linearization_level                                           1
# log_search_progress                                        True
# max_presolve_iterations                                       3
# max_time_in_seconds                                          30
# num_search_workers                                            2
# optimize_with_core                                        False
# probing_deterministic_time_limit                            1.0
# random_seed                                                   1
# subsolvers                                                 None
# symmetry_detection_deterministic_time_limit                   1
# symmetry_level                                                2
# use_lns_only                                              False
# use_symmetry_in_lp                                        False
#
#                                                symmetry_level_3  \
# best_bound                                                   13
# booleans                                                  51153
# branches                                                   5739
# conflicts                                                     0
# deterministic_time                                           38
# gap_integral                                                361
# integer_propagations                                     232934
# integers                                                  63226
# lp_iterations                                                 0
# objective                                                 15504
# propagations                                              59947
# restarts                                                   5739
# run_timestamp                                        1741112648
# solution_fingerprint                         0xb5db6bf2a1d1e901
# status                                                 FEASIBLE
# usertime                                                     32
# walltime                                                     32
# ---
# core_minimization_level                                       2
# cp_model_probing_level                                        2
# detect_table_with_cost                                    False
# diversify_lns_params                                      False
# interleave_search                                         False
# linearization_level                                           1
# log_search_progress                                        True
# max_presolve_iterations                                       3
# max_time_in_seconds                                          30
# num_search_workers                                           16
# optimize_with_core                                        False
# probing_deterministic_time_limit                            1.0
# random_seed                                                   1
# subsolvers                                                 None
# symmetry_detection_deterministic_time_limit                   1
# symmetry_level                                                2
# use_lns_only                                              False
# use_symmetry_in_lp                                        False
#
#                                                symmetry_level_4  \
# best_bound                                                   13
# booleans                                                  51153
# branches                                                 131794
# conflicts                                                     0
# deterministic_time                                           16
# gap_integral                                                177
# integer_propagations                                    4805529
# integers                                                  63497
# lp_iterations                                             28477
# objective                                                242914
# propagations                                            1197300
# restarts                                                 102306
# run_timestamp                                        1741104525
# solution_fingerprint                         0xbfa84bd2c337408f
# status                                                 FEASIBLE
# usertime                                                     30
# walltime                                                     30
# ---
# core_minimization_level                                       2
# cp_model_probing_level                                        2
# detect_table_with_cost                                    False
# diversify_lns_params                                      False
# interleave_search                                         False
# linearization_level                                           1
# log_search_progress                                        True
# max_presolve_iterations                                       3
# max_time_in_seconds                                          30
# num_search_workers                                            2
# optimize_with_core                                        False
# probing_deterministic_time_limit                            0.5
# random_seed                                                   1
# subsolvers                                                 None
# symmetry_detection_deterministic_time_limit                   1
# symmetry_level                                                2
# use_lns_only                                              False
# use_symmetry_in_lp                                        False
#
#                                               use_lns_only_True  \
# best_bound                                                   13
# booleans                                                  51153
# branches                                                 131117
# conflicts                                                     0
# deterministic_time                                           16
# gap_integral                                                177
# integer_propagations                                    4798863
# integers                                                  63497
# lp_iterations                                             28411
# objective                                                272049
# propagations                                            1196858
# restarts                                                 102306
# run_timestamp                                        1741106254
# solution_fingerprint                         0x8bf0af42564d0ebe
# status                                                 FEASIBLE
# usertime                                                     30
# walltime                                                     30
# ---
# core_minimization_level                                       2
# cp_model_probing_level                                        2
# detect_table_with_cost                                    False
# diversify_lns_params                                      False
# interleave_search                                         False
# linearization_level                                           1
# log_search_progress                                        True
# max_presolve_iterations                                       5
# max_time_in_seconds                                          30
# num_search_workers                                            2
# optimize_with_core                                        False
# probing_deterministic_time_limit                            1.0
# random_seed                                                   1
# subsolvers                                                 None
# symmetry_detection_deterministic_time_limit                   1
# symmetry_level                                                2
# use_lns_only                                              False
# use_symmetry_in_lp                                        False
#
#                                             use_symmetry_in_lp_True
# best_bound                                                       13
# booleans                                                      51153
# branches                                                     131328
# conflicts                                                         0
# deterministic_time                                               16
# gap_integral                                                    177
# integer_propagations                                        4800947
# integers                                                      63497
# lp_iterations                                                 28439
# objective                                                    249412
# propagations                                                1197003
# restarts                                                     102306
# run_timestamp                                            1741107984
# solution_fingerprint                             0x478b310eb163e380
# status                                                     FEASIBLE
# usertime                                                         30
# walltime                                                         30
# ---
# core_minimization_level                                           2
# cp_model_probing_level                                            2
# detect_table_with_cost                                         True
# diversify_lns_params                                          False
# interleave_search                                             False
# linearization_level                                               1
# log_search_progress                                            True
# max_presolve_iterations                                           3
# max_time_in_seconds                                              30
# num_search_workers                                                2
# optimize_with_core                                            False
# probing_deterministic_time_limit                                1.0
# random_seed                                                       1
# subsolvers                                                     None
# symmetry_detection_deterministic_time_limit                       1
# symmetry_level                                                    2
# use_lns_only                                                  False
# use_symmetry_in_lp                                            False
#
# [36 rows x 31 columns]
